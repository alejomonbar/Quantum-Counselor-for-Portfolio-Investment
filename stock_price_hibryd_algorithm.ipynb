# %% [markdown]
# ## **Importing Libraries**
#
# A library was built with the name tfqml.py to store all the dependencies, classes and methods that are used in this work, these classes are
# - ClassicalPreprocessing,
# - QuantumPreprocessing,
# - CircuitLayer,
# - QuantumModel-
#
# together with the methods
# - visualization and
# - save_data
#
#
# the dependencies are:
# - numpy
# - pandas
# - matplotlib
# - sklearn
# - cirq
# - tensorflow_quantum
# - tensorflow
# - sympy

# %%
from tfqml import *
# Out:
# 2022-02-25 08:05:23.884557: W tensorflow/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libcudart.so.11.0'; dlerror: libcudart.so.11.0: cannot open shared object file: No such file or directory
# 2022-02-25 08:05:23.884577: I tensorflow/stream_executor/cuda/cudart_stub.cc:29] Ignore above cudart dlerror if you do not have a GPU set up on your machine.
# 2022-02-25 08:05:25.243971: E tensorflow/stream_executor/cuda/cuda_driver.cc:271] failed call to cuInit: CUDA_ERROR_NO_DEVICE: no CUDA-capable device is detected
# 2022-02-25 08:05:25.243994: I tensorflow/stream_executor/cuda/cuda_diagnostics.cc:156] kernel driver does not appear to be running on this host (toto): /proc/driver/nvidia/version does not exist
# 2022-02-25 08:05:25.244517: I tensorflow/core/platform/cpu_feature_guard.cc:151] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2 FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.

# %% [markdown]
# ## **Choose the 8 stocks**
#
# we select 8 stocks from 8 conglomerates based on the dataset of Xu et al. [[2]](https://aclanthology.org/P18-1183/):
#
# - Basic Materials: TOTAL S.A. "TOT"
#
# - Consumer Goods: Appel Inc. "AAPL"
#
# - Healthcare: AbbVie Inc. "ABBV"
#
# - Services: Wall-Mart Stores Inc. "WMT"
#
# - Utilites: Duke energy corporation "DUK"
#
# - Financial: HSBS Holding pcl "HSBC"
#
# - Industrial Goods: ABB Ltd. "ABB"
#
# - Technology: China Mobile Limited "CHL"

# %%
name_stocks = ['AAPL','ABB','ABBV','TOT','WMT','DUK','CHL','HSBC']

# %% [markdown]
# # Classical Preprocessing
#
# The methods of our library are used to preprocess the csv files of the 8 stocks,
# We consider 30 days por each instance and we obtain the shape of the train and test dataset

# %%
cp = ClassicalPreprocessing(filename=name_stocks[0])
days = 30
x_train,y_train,x_test,y_test = cp.preprocessing(days=days,flag_pca=True)
# Out:
# Shape of train data: (880, 1)
# Shape of test data: (378, 1)

# %% [markdown]
# At this point we can check the dataset for trai nand test and confirm is the same dimention of the days and using a normalization

# %%
x_train[0]
# Out:
# array([0.50210573, 0.5198373 , 0.5154993 , 0.52431991, 0.52865792,
#        0.50093085, 0.50407582, 0.52309078, 0.54584719, 0.56281965,
#        0.56377762, 0.56446444, 0.56247619, 0.56835058, 0.54024395,
#        0.54277451, 0.50749205, 0.49944871, 0.52558515, 0.51186616,
#        0.49496611, 0.50047898, 0.51202891, 0.5010935 , 0.46798009,
#        0.45310439, 0.45507448, 0.46729319, 0.43667413, 0.44171711])

# %% [markdown]
# # Quantum Pre processing
#
# Convert the classical information fo the train and test dataset into a quantumcircuit this is possible using cirq, for this proposal we consider two encoding method, amplitude and angle, we keep the last one, for its result it was very well with respect the amplitude. Using as reference this the paper [Quantum Long Short-Term Memory](https://arxiv.org/pdf/2009.01783.pdf)  for the encoding, is important apply the arctang of the data and add a proposal. It was proposed for this encoding to reduce the number of qubits with the consideration that there are 30 data, one for each of the 3 coordinates, therefore the number of days divided by 3 will have to be used, it should be noted that data of multiples of 3 are needed to use this encoding.

# %%
qp = QuantumPreprocessing(x_train,x_test)
x_trainq,x_testq = qp.data2qubits()

# %% [markdown]
# Print a quantum circuit of our encoding, apart of the angle we add a Hadamard prevous the X and Z rotation and  do an entenglament for each pair of qubits. You can see in the next cell

# %%
qp.print_circuit(0)
# Out:
# findfont: Font family ['Arial'] not found. Falling back to DejaVu Sans.

# %% [markdown]
# following with the idea that they must be multiples of 3, the ansatz is used and this is designed with a layer of RY followed by CX with the qubit target of each CX applying an RY and then an H and the same is done with the RX gate, the number of parameters for each layer is indicated. these are 15 per layer. We use reference the tutorial from [tensorflow Quantum](https://www.tensorflow.org/quantum/tutorials/mnist)

# %%
qubits_required = days//3
qm = QuantumModel(qubits_required)
model_circuit, model_readout =qm.quantum_circuit([cirq.Y,cirq.X])
SVGCircuit(model_circuit)

# %% [markdown]
# Creating our LSTM hibryd model.The first layer is our proposal which input is 30 parameters per instance and output is 10, followed by LSTM and Dropout layers, at the end a Dense layer to have an output value.

# %%
# Build the Keras model.
model = tf.keras.Sequential([
    # The input is the data-circuit, encoded as a tf.string
    tf.keras.layers.Input(shape=(), dtype=tf.string),
    # The PQC layer returns the expected value of the readout gate.
    tfq.layers.PQC(model_circuit, model_readout),
    tf.keras.layers.Reshape((1,10)),
    tf.keras.layers.LSTM(units=100, return_sequences=True),
    tf.keras.layers.Dropout(0.2),
    tf.keras.layers.LSTM(units=100, return_sequences=True),
    tf.keras.layers.Dropout(0.2),
    tf.keras.layers.LSTM(units=5),
    tf.keras.layers.Dense(units=1),
])

# %% [markdown]
# Apply the as loss the MSE and optimizer ADAM

# %%
model.compile(
    loss='mean_squared_error',
    optimizer=tf.keras.optimizers.Adam(),
    metrics=[tf.keras.metrics.RootMeanSquaredError()])

print(model.summary())
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  pqc (PQC)                   (None, 10)                30
#
#  reshape (Reshape)           (None, 1, 10)             0
#
#  lstm (LSTM)                 (None, 1, 100)            44400
#
#  dropout (Dropout)           (None, 1, 100)            0
#
#  lstm_1 (LSTM)               (None, 1, 100)            80400
#
#  dropout_1 (Dropout)         (None, 1, 100)            0
#
#  lstm_2 (LSTM)               (None, 5)                 2120
#
#  dense (Dense)               (None, 1)                 6
#
# =================================================================
# Total params: 126,956
# Trainable params: 126,956
# Non-trainable params: 0
# _________________________________________________________________
# None

# %% [markdown]
# Consider only 60 epoch with a batch size of 32

# %%
qnn_history = model.fit(
      x_trainq, y_train,
      batch_size=32,
      epochs=60)

qnn_results = model.evaluate(x_testq, y_test)
# Out:
# Epoch 1/60
# 27/27 [==============================] - 5s 98ms/step - loss: 0.2290 - root_mean_squared_error: 0.4785
# Epoch 2/60
# 27/27 [==============================] - 3s 100ms/step - loss: 0.0369 - root_mean_squared_error: 0.1921
# Epoch 3/60
# 27/27 [==============================] - 3s 96ms/step - loss: 0.0103 - root_mean_squared_error: 0.1014
# Epoch 4/60
# 27/27 [==============================] - 3s 98ms/step - loss: 0.0076 - root_mean_squared_error: 0.0874
# Epoch 5/60
# 27/27 [==============================] - 3s 103ms/step - loss: 0.0069 - root_mean_squared_error: 0.0830
# Epoch 6/60
# 27/27 [==============================] - 3s 108ms/step - loss: 0.0065 - root_mean_squared_error: 0.0807
# Epoch 7/60
# 27/27 [==============================] - 3s 103ms/step - loss: 0.0060 - root_mean_squared_error: 0.0775
# Epoch 8/60
# 27/27 [==============================] - 3s 102ms/step - loss: 0.0055 - root_mean_squared_error: 0.0741
# Epoch 9/60
# 27/27 [==============================] - 3s 100ms/step - loss: 0.0049 - root_mean_squared_error: 0.0702
# Epoch 10/60
# 27/27 [==============================] - 3s 106ms/step - loss: 0.0043 - root_mean_squared_error: 0.0657
# Epoch 11/60
# 27/27 [==============================] - 3s 102ms/step - loss: 0.0042 - root_mean_squared_error: 0.0651
# Epoch 12/60
# 27/27 [==============================] - 3s 109ms/step - loss: 0.0042 - root_mean_squared_error: 0.0645
# Epoch 13/60
# 27/27 [==============================] - 3s 103ms/step - loss: 0.0037 - root_mean_squared_error: 0.0606
# Epoch 14/60
# 27/27 [==============================] - 3s 107ms/step - loss: 0.0030 - root_mean_squared_error: 0.0548
# Epoch 15/60
# 27/27 [==============================] - 3s 103ms/step - loss: 0.0030 - root_mean_squared_error: 0.0550
# Epoch 16/60
# 27/27 [==============================] - 3s 96ms/step - loss: 0.0025 - root_mean_squared_error: 0.0505
# Epoch 17/60
# 27/27 [==============================] - 3s 99ms/step - loss: 0.0027 - root_mean_squared_error: 0.0518
# Epoch 18/60
# 27/27 [==============================] - 3s 103ms/step - loss: 0.0024 - root_mean_squared_error: 0.0486
# Epoch 19/60
# 27/27 [==============================] - 3s 96ms/step - loss: 0.0023 - root_mean_squared_error: 0.0481
# Epoch 20/60
# 27/27 [==============================] - 3s 96ms/step - loss: 0.0023 - root_mean_squared_error: 0.0476
# Epoch 21/60
# 27/27 [==============================] - 3s 100ms/step - loss: 0.0021 - root_mean_squared_error: 0.0459
# Epoch 22/60
# 27/27 [==============================] - 3s 102ms/step - loss: 0.0020 - root_mean_squared_error: 0.0447
# Epoch 23/60
# 27/27 [==============================] - 3s 96ms/step - loss: 0.0021 - root_mean_squared_error: 0.0459
# Epoch 24/60
# 27/27 [==============================] - 3s 94ms/step - loss: 0.0021 - root_mean_squared_error: 0.0459
# Epoch 25/60
# 27/27 [==============================] - 2s 89ms/step - loss: 0.0019 - root_mean_squared_error: 0.0437
# Epoch 26/60
# 27/27 [==============================] - 3s 101ms/step - loss: 0.0018 - root_mean_squared_error: 0.0423
# Epoch 27/60
# 27/27 [==============================] - 3s 108ms/step - loss: 0.0018 - root_mean_squared_error: 0.0429
# Epoch 28/60
# 27/27 [==============================] - 3s 102ms/step - loss: 0.0018 - root_mean_squared_error: 0.0424
# Epoch 29/60
# 27/27 [==============================] - 3s 97ms/step - loss: 0.0018 - root_mean_squared_error: 0.0419
# Epoch 30/60
# 27/27 [==============================] - 3s 93ms/step - loss: 0.0018 - root_mean_squared_error: 0.0420
# Epoch 31/60
# 27/27 [==============================] - 3s 95ms/step - loss: 0.0018 - root_mean_squared_error: 0.0427
# Epoch 32/60
# 27/27 [==============================] - 2s 92ms/step - loss: 0.0017 - root_mean_squared_error: 0.0413
# Epoch 33/60
# 27/27 [==============================] - 3s 97ms/step - loss: 0.0017 - root_mean_squared_error: 0.0413
# Epoch 34/60
# 27/27 [==============================] - 2s 91ms/step - loss: 0.0016 - root_mean_squared_error: 0.0395
# Epoch 35/60
# 27/27 [==============================] - 2s 92ms/step - loss: 0.0016 - root_mean_squared_error: 0.0405
# Epoch 36/60
# 27/27 [==============================] - 3s 93ms/step - loss: 0.0016 - root_mean_squared_error: 0.0400
# Epoch 37/60
# 27/27 [==============================] - 2s 90ms/step - loss: 0.0016 - root_mean_squared_error: 0.0397
# Epoch 38/60
# 27/27 [==============================] - 2s 89ms/step - loss: 0.0015 - root_mean_squared_error: 0.0384
# Epoch 39/60
# 27/27 [==============================] - 3s 101ms/step - loss: 0.0015 - root_mean_squared_error: 0.0393
# Epoch 40/60
# 27/27 [==============================] - 3s 99ms/step - loss: 0.0017 - root_mean_squared_error: 0.0416
# Epoch 41/60
# 27/27 [==============================] - 3s 94ms/step - loss: 0.0015 - root_mean_squared_error: 0.0394
# Epoch 42/60
# 27/27 [==============================] - 3s 98ms/step - loss: 0.0015 - root_mean_squared_error: 0.0393
# Epoch 43/60
# 27/27 [==============================] - 3s 96ms/step - loss: 0.0015 - root_mean_squared_error: 0.0386
# Epoch 44/60
# 27/27 [==============================] - 3s 99ms/step - loss: 0.0015 - root_mean_squared_error: 0.0389
# Epoch 45/60
# 27/27 [==============================] - 2s 91ms/step - loss: 0.0015 - root_mean_squared_error: 0.0384
# Epoch 46/60
# 27/27 [==============================] - 3s 92ms/step - loss: 0.0014 - root_mean_squared_error: 0.0379
# Epoch 47/60
# 27/27 [==============================] - 3s 93ms/step - loss: 0.0014 - root_mean_squared_error: 0.0367
# Epoch 48/60
# 27/27 [==============================] - 3s 97ms/step - loss: 0.0013 - root_mean_squared_error: 0.0366
# Epoch 49/60
# 27/27 [==============================] - 3s 97ms/step - loss: 0.0014 - root_mean_squared_error: 0.0376
# Epoch 50/60
# 27/27 [==============================] - 3s 95ms/step - loss: 0.0015 - root_mean_squared_error: 0.0382
# Epoch 51/60
# 27/27 [==============================] - 3s 97ms/step - loss: 0.0014 - root_mean_squared_error: 0.0372
# Epoch 52/60
# 27/27 [==============================] - 3s 98ms/step - loss: 0.0013 - root_mean_squared_error: 0.0360
# Epoch 53/60
# 27/27 [==============================] - 3s 92ms/step - loss: 0.0014 - root_mean_squared_error: 0.0375
# Epoch 54/60
# 27/27 [==============================] - 3s 99ms/step - loss: 0.0014 - root_mean_squared_error: 0.0374
# Epoch 55/60
# 27/27 [==============================] - 3s 97ms/step - loss: 0.0013 - root_mean_squared_error: 0.0367
# Epoch 56/60
# 27/27 [==============================] - 2s 91ms/step - loss: 0.0013 - root_mean_squared_error: 0.0359
# Epoch 57/60
# 27/27 [==============================] - 3s 95ms/step - loss: 0.0014 - root_mean_squared_error: 0.0368
# Epoch 58/60
# 27/27 [==============================] - 3s 94ms/step - loss: 0.0014 - root_mean_squared_error: 0.0368
# Epoch 59/60
# 27/27 [==============================] - 2s 88ms/step - loss: 0.0012 - root_mean_squared_error: 0.0353
# Epoch 60/60
# 27/27 [==============================] - 2s 91ms/step - loss: 0.0012 - root_mean_squared_error: 0.0349
# 11/11 [==============================] - 1s 52ms/step - loss: 0.0124 - root_mean_squared_error: 0.1115

# %% [markdown]
# Plot the result between the  real and predict with both data set, train and test.

# %%
visualization(model,x_trainq,y_train)
visualization(model,x_testq,y_test)

# %% [markdown]
# Finally, we save the model and outputs, the proposal save this model.

# %%
save_data(model,x_trainq,y_train,name_stocks[1]+"_train")
save_data(model,x_testq,y_test,name_stocks[1]+"_test")
