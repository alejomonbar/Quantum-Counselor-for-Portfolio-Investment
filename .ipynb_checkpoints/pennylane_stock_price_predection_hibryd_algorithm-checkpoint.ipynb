# %% [markdown]
# ## **Importing Libraries**

# %%
from tfqml import *
import pennylane as qml
# Out:
# 2022-02-24 15:36:07.524240: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:939] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-02-24 15:36:07.555702: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:939] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-02-24 15:36:07.555939: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:939] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-02-24 15:36:07.556670: I tensorflow/core/platform/cpu_feature_guard.cc:151] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2 FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2022-02-24 15:36:07.557326: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:939] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-02-24 15:36:07.557495: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:939] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-02-24 15:36:07.557647: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:939] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-02-24 15:36:07.938975: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:939] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-02-24 15:36:07.939159: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:939] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-02-24 15:36:07.939310: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:939] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-02-24 15:36:07.939445: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1525] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 5964 MB memory:  -> device: 0, name: NVIDIA GeForce RTX 3070, pci bus id: 0000:01:00.0, compute capability: 8.6

# %% [markdown]
# ## **Choose the 8 stocks**

# %%
name_stocks = ['AAPL','ABB','ABBV','TOT','WMT','DUK','CHL','HSBC']

# %% [markdown]
# # Classical Preprocessing

# %%
index = 6

# %%
cp = ClassicalPreprocessing(filename=name_stocks[index])
days = 30
x_train,y_train,x_test,y_test = cp.preprocessing(days=days,flag_pca=True)
# Out:
# Shape of train data: (880, 1)
# Shape of test data: (378, 1)

# %% [markdown]
# # Quantum Pre processing

# %%
n_qubits = days//3

dev = qml.device("default.qubit.tf", wires=n_qubits)

@qml.qnode(dev)
def qnode(inputs,weights_0,weights_1,weights_2,weights_3):
    for i in range(10):
        qml.RY(np.arctan(inputs[i]),wires=i)
        qml.Hadamard(i)
        qml.RY(np.arctan(inputs[10+i]),wires=i)
    
    qml.CNOT(wires=[0, 1])
    qml.CNOT(wires=[2, 3])
    qml.CNOT(wires=[4, 5])
    qml.CNOT(wires=[6, 7])
    qml.CNOT(wires=[8, 9])
    for i in range(10):
        qml.RZ(np.arctan(inputs[20+i]),wires=i)
    
    
    for j,w in enumerate(weights_0):
        qml.RY(w, wires=j)
        

    qml.CNOT(wires=[0, 1])
    
    qml.CNOT(wires=[4, 3])
    
    qml.CNOT(wires=[3, 2])    
    
    qml.CNOT(wires=[2, 1])
    
    list_index = [1,3,5,7,9]
    for j,w in enumerate(weights_1):
        qml.RY(w, wires=list_index[j])     
        

    qml.Hadamard(1)
    qml.Hadamard(3)
    qml.Hadamard(5)
    qml.Hadamard(7)
    qml.Hadamard(9)
    
    for j,w in enumerate(weights_2):
        qml.RX(w, wires=j)
    
    qml.CNOT(wires=[0, 1])
    
    qml.CNOT(wires=[4, 3])
    
    qml.CNOT(wires=[3, 2])    
    
    qml.CNOT(wires=[2, 1])
    
    list_index = [1,3,5,7,9]
    for j,w in enumerate(weights_3):
        qml.RX(w, wires=list_index[j])     
        
    qml.Hadamard(1)
    qml.Hadamard(3)
    qml.Hadamard(5)
    qml.Hadamard(7)
    qml.Hadamard(9)
    return qml.expval(qml.PauliZ(0)), qml.expval(qml.PauliZ(1)), qml.expval(qml.PauliZ(2)), qml.expval(qml.PauliZ(3)), qml.expval(qml.PauliZ(4)),qml.expval(qml.PauliZ(5)), qml.expval(qml.PauliZ(6)), qml.expval(qml.PauliZ(7)), qml.expval(qml.PauliZ(8)), qml.expval(qml.PauliZ(9))
        
weight_shapes = {"weights_0": 10, "weights_1": 5, "weights_2": 10, "weights_3": 5}#,"weights_5": 1,"weights_6": 1,"weights_7": 1,"weights_8": 1,"weights_9": 1}
qlayer = qml.qnn.KerasLayer(qnode, weight_shapes, output_dim=10)

# %%
model = tf.keras.models.Sequential()

model.add(tf.keras.layers.Input(shape=()))

model.add(qlayer)
model.add(tf.keras.layers.Reshape((1,10)))
model.add(tf.keras.layers.LSTM(units=100, return_sequences=True))
model.add(tf.keras.layers.Dropout(0.2))
model.add(tf.keras.layers.LSTM(units=100, return_sequences=True))
model.add(tf.keras.layers.Dropout(0.2))
model.add(tf.keras.layers.LSTM(units=5))
model.add(tf.keras.layers.Dense(units=1))

# %%
model.compile(
    loss='mean_squared_error',
    optimizer=tf.keras.optimizers.Adam(),
    metrics=[tf.keras.metrics.RootMeanSquaredError()])

model.build()

print(model.summary())
# Out:
# Model: "sequential_13"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  keras_layer_8 (KerasLayer)  (None, 10)                0 (unused)
#
#  reshape_13 (Reshape)        (None, 1, 10)             0
#
#  lstm_15 (LSTM)              (None, 1, 100)            44400
#
#  dropout_10 (Dropout)        (None, 1, 100)            0
#
#  lstm_16 (LSTM)              (None, 1, 100)            80400
#
#  dropout_11 (Dropout)        (None, 1, 100)            0
#
#  lstm_17 (LSTM)              (None, 5)                 2120
#
#  dense_5 (Dense)             (None, 1)                 6
#
# =================================================================
# Total params: 126,926
# Trainable params: 126,926
# Non-trainable params: 0
# _________________________________________________________________
# None

# %%
qnn_history = model.fit(
      tf.constant(x_train), y_train,
      batch_size=32,
      epochs=15)

qnn_results = model.evaluate(tf.constant(x_test), y_test)
# Out:
# Epoch 1/60
# 2022-02-24 16:37:14.777530: I tensorflow/stream_executor/cuda/cuda_dnn.cc:366] Loaded cuDNN version 8202
# 2022-02-24 16:37:14.910018: I tensorflow/stream_executor/cuda/cuda_blas.cc:1774] TensorFloat-32 will be used for the matrix multiplication. This will only be logged once.
# 27/27 [==============================] - 139s 5s/step - loss: 0.2112 - root_mean_squared_error: 0.4595
# Epoch 2/60
# 27/27 [==============================] - 139s 5s/step - loss: 0.0483 - root_mean_squared_error: 0.2198
# Epoch 3/60
# 27/27 [==============================] - 139s 5s/step - loss: 0.0390 - root_mean_squared_error: 0.1975
# Epoch 4/60
# 27/27 [==============================] - 140s 5s/step - loss: 0.0336 - root_mean_squared_error: 0.1832
# Epoch 5/60
# 27/27 [==============================] - 140s 5s/step - loss: 0.0284 - root_mean_squared_error: 0.1684
# Epoch 6/60
# 27/27 [==============================] - 140s 5s/step - loss: 0.0201 - root_mean_squared_error: 0.1419
# Epoch 7/60
# 27/27 [==============================] - 141s 5s/step - loss: 0.0115 - root_mean_squared_error: 0.1072
# Epoch 8/60
# 27/27 [==============================] - 142s 5s/step - loss: 0.0076 - root_mean_squared_error: 0.0870
# Epoch 9/60
# 27/27 [==============================] - 142s 5s/step - loss: 0.0061 - root_mean_squared_error: 0.0780
# Epoch 10/60
# 27/27 [==============================] - 142s 5s/step - loss: 0.0064 - root_mean_squared_error: 0.0799
# Epoch 11/60
# 27/27 [==============================] - 141s 5s/step - loss: 0.0059 - root_mean_squared_error: 0.0769
# Epoch 12/60
# 27/27 [==============================] - 143s 5s/step - loss: 0.0053 - root_mean_squared_error: 0.0729
# Epoch 13/60
# 27/27 [==============================] - 141s 5s/step - loss: 0.0051 - root_mean_squared_error: 0.0715
# Epoch 14/60
# 27/27 [==============================] - 140s 5s/step - loss: 0.0046 - root_mean_squared_error: 0.0682
# Epoch 15/60
# 27/27 [==============================] - 141s 5s/step - loss: 0.0046 - root_mean_squared_error: 0.0677
# Epoch 16/60
# 27/27 [==============================] - 141s 5s/step - loss: 0.0046 - root_mean_squared_error: 0.0680
# Epoch 17/60
# 27/27 [==============================] - 143s 5s/step - loss: 0.0042 - root_mean_squared_error: 0.0647
# Epoch 18/60
# 27/27 [==============================] - 143s 5s/step - loss: 0.0038 - root_mean_squared_error: 0.0619
# Epoch 19/60
# 27/27 [==============================] - 142s 5s/step - loss: 0.0040 - root_mean_squared_error: 0.0630
# Epoch 20/60
# 27/27 [==============================] - 142s 5s/step - loss: 0.0037 - root_mean_squared_error: 0.0612
# Epoch 21/60
# 27/27 [==============================] - 139s 5s/step - loss: 0.0038 - root_mean_squared_error: 0.0614
# Epoch 22/60
# 27/27 [==============================] - 134s 5s/step - loss: 0.0037 - root_mean_squared_error: 0.0611
# Epoch 23/60
# 27/27 [==============================] - 134s 5s/step - loss: 0.0036 - root_mean_squared_error: 0.0603
# Epoch 24/60
# 27/27 [==============================] - 134s 5s/step - loss: 0.0034 - root_mean_squared_error: 0.0584
# Epoch 25/60
# 27/27 [==============================] - 133s 5s/step - loss: 0.0034 - root_mean_squared_error: 0.0586
# Epoch 26/60
# 27/27 [==============================] - 134s 5s/step - loss: 0.0033 - root_mean_squared_error: 0.0574
# Epoch 27/60
# 27/27 [==============================] - 133s 5s/step - loss: 0.0034 - root_mean_squared_error: 0.0579
# Epoch 28/60
# 27/27 [==============================] - 135s 5s/step - loss: 0.0033 - root_mean_squared_error: 0.0578
# Epoch 29/60
# 27/27 [==============================] - 134s 5s/step - loss: 0.0034 - root_mean_squared_error: 0.0580
# Epoch 30/60
# 27/27 [==============================] - 135s 5s/step - loss: 0.0033 - root_mean_squared_error: 0.0573
# Epoch 31/60
# 27/27 [==============================] - 137s 5s/step - loss: 0.0032 - root_mean_squared_error: 0.0567
# Epoch 32/60
# 27/27 [==============================] - 134s 5s/step - loss: 0.0032 - root_mean_squared_error: 0.0562
# Epoch 33/60
# 27/27 [==============================] - 134s 5s/step - loss: 0.0033 - root_mean_squared_error: 0.0570
# Epoch 34/60
# 27/27 [==============================] - 134s 5s/step - loss: 0.0031 - root_mean_squared_error: 0.0558
# Epoch 35/60
# 27/27 [==============================] - 134s 5s/step - loss: 0.0030 - root_mean_squared_error: 0.0549
# Epoch 36/60
# 27/27 [==============================] - 134s 5s/step - loss: 0.0030 - root_mean_squared_error: 0.0546
# Epoch 37/60
# 27/27 [==============================] - 134s 5s/step - loss: 0.0031 - root_mean_squared_error: 0.0558
# Epoch 38/60
# 27/27 [==============================] - 135s 5s/step - loss: 0.0028 - root_mean_squared_error: 0.0532
# Epoch 39/60
# 27/27 [==============================] - 136s 5s/step - loss: 0.0030 - root_mean_squared_error: 0.0549
# Epoch 40/60
# 27/27 [==============================] - 135s 5s/step - loss: 0.0030 - root_mean_squared_error: 0.0549
# Epoch 41/60
# 27/27 [==============================] - 137s 5s/step - loss: 0.0028 - root_mean_squared_error: 0.0533
# Epoch 42/60
# 27/27 [==============================] - 134s 5s/step - loss: 0.0028 - root_mean_squared_error: 0.0533
# Epoch 43/60
# 27/27 [==============================] - 136s 5s/step - loss: 0.0028 - root_mean_squared_error: 0.0532
# Epoch 44/60
# 27/27 [==============================] - 136s 5s/step - loss: 0.0027 - root_mean_squared_error: 0.0521
# Epoch 45/60
# 27/27 [==============================] - 135s 5s/step - loss: 0.0028 - root_mean_squared_error: 0.0531
# Epoch 46/60
# 27/27 [==============================] - 135s 5s/step - loss: 0.0028 - root_mean_squared_error: 0.0526
# Epoch 47/60
# 27/27 [==============================] - 137s 5s/step - loss: 0.0028 - root_mean_squared_error: 0.0525
# Epoch 48/60
# 27/27 [==============================] - 136s 5s/step - loss: 0.0027 - root_mean_squared_error: 0.0523
# Epoch 49/60
# 27/27 [==============================] - 136s 5s/step - loss: 0.0025 - root_mean_squared_error: 0.0498
# Epoch 50/60
# 27/27 [==============================] - 135s 5s/step - loss: 0.0028 - root_mean_squared_error: 0.0526
# Epoch 51/60
# 27/27 [==============================] - 140s 5s/step - loss: 0.0025 - root_mean_squared_error: 0.0505
# Epoch 52/60
# 27/27 [==============================] - 140s 5s/step - loss: 0.0025 - root_mean_squared_error: 0.0504
# Epoch 53/60
# 27/27 [==============================] - 141s 5s/step - loss: 0.0025 - root_mean_squared_error: 0.0502
# Epoch 54/60
# 27/27 [==============================] - 141s 5s/step - loss: 0.0026 - root_mean_squared_error: 0.0513
# Epoch 55/60
# 27/27 [==============================] - 140s 5s/step - loss: 0.0026 - root_mean_squared_error: 0.0511
# Epoch 56/60
# 27/27 [==============================] - 140s 5s/step - loss: 0.0025 - root_mean_squared_error: 0.0495
# Epoch 57/60
# 27/27 [==============================] - 140s 5s/step - loss: 0.0024 - root_mean_squared_error: 0.0493
# Epoch 58/60
# 27/27 [==============================] - 142s 5s/step - loss: 0.0025 - root_mean_squared_error: 0.0501
# Epoch 59/60
# 27/27 [==============================] - 144s 5s/step - loss: 0.0025 - root_mean_squared_error: 0.0497
# Epoch 60/60
# 27/27 [==============================] - 143s 5s/step - loss: 0.0024 - root_mean_squared_error: 0.0489
# 11/11 [==============================] - 36s 3s/step - loss: 0.0018 - root_mean_squared_error: 0.0423

# %%
visualization(model,tf.constant(x_train),y_train)
visualization(model,tf.constant(x_test),y_test)

# %%
iteration= 0
save_data(model,x_train,y_train,"pennylane_"+name_stocks[index]+"_"+str(iteration)+"_train")
save_data(model,x_test,y_test,"pennylane_"+name_stocks[index]+"_"+str(iteration)+"_test")
# Out:
# MAE 3.33%
# MAE 3.29%
